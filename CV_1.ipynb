# %% [markdown]
# Illustrate image Manipulation operation

# %% [markdown]
# It is a process of bringing changes to a digitized image for transforming it to a desired image

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2 as cv
img=cv.imread('/content/drive/MyDrive/ComputerVision/9a.jpg',255)
plt.imshow(img, cmap="gray")

# %%
from PIL import Image, ImageFilter
#Read image
img = Image.open( '/content/drive/MyDrive/ComputerVision/9a.jpg' )
#Display image
img.show()
 

from PIL import ImageEnhance
enh = ImageEnhance.Contrast(img)
enh.enhance(1.8).show("30% more contrast")
plt.imshow(img)

# %%
from scipy import misc,ndimage
 

face = misc.face('/content/drive/MyDrive/ComputerVision/9a.jpg')
blurred_face = ndimage.gaussian_filter(face, sigma=3)
very_blurred = ndimage.gaussian_filter(face, sigma=5)


plt.imshow(face)
